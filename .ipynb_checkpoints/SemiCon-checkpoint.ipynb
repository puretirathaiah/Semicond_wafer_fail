# %% [markdown]
# # Wafer fault detection in semiconductor manufacturing <br>
#
# "<b>Dataset information</b>:
#
# A complex modern semi-conductor manufacturing process is normally under consistent surveillance via the monitoring of signals/variables collected from sensors and or process measurement points. However, not all of these signals are equally valuable in a specific monitoring system. The measured signals contain a combination of useful information, irrelevant information as well as noise. It is often the case that useful information is buried in the latter two. Engineers typically have a much larger number of signals than are actually required. If we consider each type of signal as a feature, then feature selection may be applied to identify the most relevant signals. The Process Engineers may then use these signals to determine key factors contributing to yield excursions downstream in the process. This will enable an increase in process throughput, decreased time to learning and reduce the per unit production costs.
#
# To enhance current business improvement techniques the application of feature selection as an intelligent systems technique is being investigated.
#
# The dataset presented in this case represents a selection of such features where each example represents a single production entity with associated measured features and the labels represent a simple pass/fail yield for in house line testing, figure 2, and associated date time stamp. Where –1 corresponds to a pass and 1 corresponds to a fail and the data time stamp is for that specific test point."
#
# <b>Source</b>: https://archive.ics.uci.edu/ml/datasets/SECOM
#
# <b>Objective</b>: Train a machine learning model to predict whether a wafer is faulty one or not using the data received from different sensors
# <b>Methodology</b>: This work involved different steps as listed below:
# - Understanding the data
# - Feature engineering (a reduction in the number of features and feature scaling)
# - Model training and evaluation
# - Undersampling and oversampling of the skewed dataset
#     - Model training and evaluation on the undersampled and oversampled datasets
# - Feature extraction using Principal component analysis
#     - Model training and evaluation on the principal components
# - summary

# %% [markdown]
# # Import the required libraries

# %%
# import the needed libraries
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV

from sklearn.model_selection import cross_val_predict
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import RocCurveDisplay

from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

from imblearn.under_sampling import CondensedNearestNeighbour
from imblearn.over_sampling import SMOTE

from sklearn.decomposition import PCA

# %% [markdown]
# # Data Preparation

# %%
# features
X = pd.read_csv('./data/secom.data', sep=' ', header=None)

# labels
y = pd.read_csv('./data/secom_labels.data', sep=' ', header=None)
y = y.loc[:, [0]]

data = pd.concat([X, y], axis=1)
data.columns.values[-1] = len(data.columns)

cols_with_nulls = [i for i,col_null_sum in enumerate (data.isnull().sum()) if col_null_sum>0]

print(data.info())
print(f'size of the data: {data.shape}')
print(f'number of cells with null values: {sum(data.isnull().sum())}')
print(f'percentage of cells with null values: {round(100 * sum(data.isnull().sum())/data.size, 2)} %')
print(f'number of labels with null values: {sum(y.isnull())}')
print(f'number of columns with null values:{len(cols_with_nulls)}')
print(f'columns with nulls are: {cols_with_nulls}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1567 entries, 0 to 1566
# Columns: 591 entries, 0 to 591
# dtypes: float64(590), int64(1)
# memory usage: 7.1 MB
# None
# size of the data: (1567, 591)
# number of cells with null values: 41951
# percentage of cells with null values: 4.53 %
# number of labels with null values: 0
# number of columns with null values:538
# ...

# %%
# replace the null values with 0 because the missed information may be not available or not calculated
# so replacing it with 0 is more meaningfull than taking the mean value
data = data.replace(np.NaN, 0)

# check again if there are null values
print(f'number of cells with null values: {np.sum(data.isnull().sum())}')
# Out:
# number of cells with null values: 0

# %% [markdown]
# ## Balanced dataset or not?

# %%
# values of the classes in label column
classes = data[data.columns[-1]].unique()

data.hist(column=data.columns[-1], legend=True)
plt.show()
plt.pie(data[data.columns[-1]].value_counts(), labels=['pass', 'fail'], colors = ['green', 'red'], 
        explode = [0, 0.1], autopct = "%.2f%%")
plt.show()

# %%
# Splitting the data into independent, dependent, and training and testing datasets
X = data.loc[:, data.columns[:-2]]
y = data.loc[:, data.columns[-1]]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # Train and evaluate the models on as-recieved data

# %%
models = [('Logistic', LogisticRegression(random_state=42, n_jobs=-1)),
          ('Rand_forest', RandomForestClassifier(random_state=42, n_jobs=-1)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    cmat = confusion_matrix(y_test, y_predict, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test, y_predict))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       0.93      0.98      0.96       440
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.92       471
#    macro avg       0.47      0.49      0.48       471
# weighted avg       0.87      0.92      0.89       471
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.96       440
#            1       0.00      0.00      0.00        31
#
#     accuracy                           0.93       471
#    macro avg       0.47      0.50      0.48       471
# weighted avg       0.87      0.93      0.90       471
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.96       440
#            1       0.25      0.06      0.10        31
#
#     accuracy                           0.93       471
# ...

# %% [markdown]
# From the confusion matrices of the three models:
# - The models provide higher accuracy (>90%)
# - Recall rate for the positive case is 0 in Logistic and Random Forest classifiers
# - GBC's recall for the positive case is approximately 10% only
# - This is primarily due to the data skewness towards negative class

# %% [markdown]
# # Feature reduction

# %%
corr_mat = np.array(data.corr())
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(corr_mat)
ax.set(xlabel='feature', ylabel='feature', title='Correlation matrix')
plt.show()

# %% [markdown]
# ## Remove highly correlated features

# %%
def remove_highly_corr_cols(data, threshold):
    """
    This function finds correlation between the columns of a dataset and 
    removes the highly correlated columns, which have the correlation higher than a threshold.
    
    Inputs: data , data frame of a dataset.
            threshold, threshold value to define highly correlated columns of the dataset.
            
    Returns: corr_col, highly correlated columns that have the correlation higher than the threshold.
             data, a dataframe with the columns of thier correlation smaller then the threshold.
    """
    corr_col = set()
    corr_mat = data.corr().abs()
    for i in range(corr_mat.shape[1]):
        for j in range(i):
            if (corr_mat.iloc[j, i] > threshold) and (not i==j) and (corr_mat.columns[i] not in corr_col):
                corr_col.add(corr_mat.columns[i])
                data.drop(corr_mat.columns[i], axis='columns', inplace=True)
            
    return corr_col, data

# %%
# Find the correlation between the features and remove highly correlated features
corr_threshold = 0.7
corr_cols, data = remove_highly_corr_cols(data, corr_threshold)
print(f'Number of cols which correlation larger than threshold: {len(corr_cols)}')
print(f'Highly correlated columns are: {np.array(corr_cols)}')
print(f'After dropping the highly correlated columns, the no. of features of the dataset is : {data.shape[1]}')
# Out:
# Number of cols which correlation larger than threshold: 284
# ...

# %%
# after removing the highly correlated features
corr_mat = np.array(data.corr())
fig, ax = plt.subplots(figsize=(10, 10))
ax.matshow(corr_mat)
ax.set(xlabel='feature', ylabel='feature', title='Correlation matrix after removing highly correlated features')
plt.show()

# %% [markdown]
# ## Split the data into dependent and independent, train and test

# %%
dataX = data.loc[:, data.columns[:-2]]
datay = data.loc[:, data.columns[-1]]

X_train, X_test, y_train, y_test = train_test_split(dataX, datay, test_size=0.30, random_state=42)

# %% [markdown]
# ## Feature scaling

# %%
ssc = StandardScaler()

X_train = ssc.fit_transform(X_train)
X_test = ssc.transform(X_test)

X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %% [markdown]
# # Train and evaluation of the models on data with reduced features

# %%
models = [('Logistic', LogisticRegression(random_state=42)),
          ('Rand_forest', RandomForestClassifier(random_state=42)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train, y_train)
    y_predict = model.predict(X_test)
    cmat = confusion_matrix(y_test, y_predict, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test, y_predict, zero_division=1))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       0.95      0.90      0.93       440
#            1       0.18      0.29      0.22        31
#
#     accuracy                           0.86       471
#    macro avg       0.56      0.60      0.57       471
# weighted avg       0.90      0.86      0.88       471
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.93      1.00      0.97       440
#            1       1.00      0.00      0.00        31
#
#     accuracy                           0.93       471
#    macro avg       0.97      0.50      0.48       471
# weighted avg       0.94      0.93      0.90       471
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.96       440
#            1       0.38      0.10      0.15        31
#
#     accuracy                           0.93       471
# ...

# %% [markdown]
# From the above confusion matrices:
# - Reduction in the number of features and normalisation improved the recall rate of the failed wafers for the Logistic regression (29%) model only
# - The requirement is to predict the failed wafers so a high recall rate would be more helpful.
# - The primary reason could be imbalanced data. Therefore, we check whether undersampling or oversampling of the passed and failed samples may improve the performance models.

# %% [markdown]
# # Undersampling of the data

# %% [markdown]
# - Imbalanced-Learn Library (imlearn) is used to perform the undersampling.
# - Condensed Nearest Neighbour technique is used.
# - It chose one-by-one samples and lists them in a store. It only lists the instances (samples) that cannot be classified correctly by the current contents of the store.
# - KNN algorithm is used to classify points to determine if they are to be added to the store or not.

# %%
# define the undersampling method
undersample = CondensedNearestNeighbour(n_neighbors=2)
      
# transform the dataset
X_us, y_us = undersample.fit_resample(dataX, datay)

#Histogram
y_us.hist(legend=True)
plt.show()

#Pie chart
plt.pie(y_us.value_counts(), labels=['pass', 'fail'], colors = ['green', 'red'], 
        explode = [0, 0.1], autopct = "%.2f%%")
plt.show()

# %%
X_train_us, X_test_us, y_train_us, y_test_us = train_test_split(X_us, y_us, test_size=0.30, random_state=42)

sss = StandardScaler()
X_train_us = ssc.fit_transform(X_train_us)
X_test_us = ssc.transform(X_test_us)

print(f'Shape of the X_train: {X_train_us.shape}')
print(f'Shape of the X_test : {X_test_us.shape}')
print(f'Shape of the y_train: {y_train_us.shape}')
print(f'Shape of the y_test : {y_test_us.shape}')
# Out:
# Shape of the X_train: (190, 305)
# Shape of the X_test : (82, 305)
# Shape of the y_train: (190,)
# Shape of the y_test : (82,)

# %% [markdown]
# ## Train and evaluation of the models on undersampled data

# %%
models = [('Logistic', LogisticRegression(random_state=42, n_jobs=-1)),
          ('Rand_forest', RandomForestClassifier(random_state=42, n_jobs=-1)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train_us, y_train_us)
    y_predict_us = model.predict(X_test_us)
    cmat = confusion_matrix(y_test_us, y_predict_us, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test_us, y_predict_us))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       0.73      0.68      0.71        53
#            1       0.48      0.55      0.52        29
#
#     accuracy                           0.63        82
#    macro avg       0.61      0.62      0.61        82
# weighted avg       0.65      0.63      0.64        82
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.66      0.91      0.76        53
#            1       0.44      0.14      0.21        29
#
#     accuracy                           0.63        82
#    macro avg       0.55      0.52      0.49        82
# weighted avg       0.58      0.63      0.57        82
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.70      0.74      0.72        53
#            1       0.46      0.41      0.44        29
#
#     accuracy                           0.62        82
# ...

# %% [markdown]
# <b>Undersampling of the (passed) samples improved the recall rate for three models. However, the improvement is not significant so the oversampling of the (failed) samples will be treid to find whether it will improve the recall rate or not.</b>

# %% [markdown]
# # Oversampling of the data

# %% [markdown]
# - Oversampling of the data can be performed using Synthetic Minority Oversampling Technique (SMOTE)
# - This technique synthesizes new examples from the minority class
#     - It chooses a random example from the minority class
#     - Next, finds the nearest neighbouring examples
#     - Out of the nearest neighbours, it randomly selects an example
#     - then, between the randomly selected two examples, it creates a random example

# %%
# define the undersampling method
oversample = SMOTE(random_state=42)

# transform the dataset
X_os, y_os = oversample.fit_resample(dataX, datay)

#Histogram
y_os.hist(legend=True)
plt.show()

#Pie chart
plt.pie(y_os.value_counts(), labels=['pass', 'fail'], colors = ['green', 'red'], 
        explode = [0, 0.1], autopct = "%.2f%%")
plt.show()

# %%
X_train_os, X_test_os, y_train_os, y_test_os = train_test_split(X_os, y_os, test_size=0.30, random_state=42)

sss = StandardScaler()
X_train_os = ssc.fit_transform(X_train_os)
X_test_os = ssc.transform(X_test_os)

print(f'Shape of the X_train: {X_train_os.shape}')
print(f'Shape of the X_test : {X_test_os.shape}')
print(f'Shape of the y_train: {y_train_os.shape}')
print(f'Shape of the y_test : {y_test_os.shape}')
# Out:
# Shape of the X_train: (2048, 305)
# Shape of the X_test : (878, 305)
# Shape of the y_train: (2048,)
# Shape of the y_test : (878,)

# %% [markdown]
# ## Train and evaluation of the models on oversampled data

# %%
models = [('Logistic', LogisticRegression(random_state=42, n_jobs=-1)),
          ('Rand_forest', RandomForestClassifier(random_state=42, n_jobs=-1)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train_os, y_train_os)
    y_predict_os = model.predict(X_test_os)
    cmat = confusion_matrix(y_test_os, y_predict_os, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test_os, y_predict_os))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       0.95      0.83      0.89       449
#            1       0.84      0.96      0.90       429
#
#     accuracy                           0.89       878
#    macro avg       0.90      0.89      0.89       878
# weighted avg       0.90      0.89      0.89       878
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.98      0.99      0.99       449
#            1       0.99      0.98      0.99       429
#
#     accuracy                           0.99       878
#    macro avg       0.99      0.99      0.99       878
# weighted avg       0.99      0.99      0.99       878
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.96      0.96      0.96       449
#            1       0.95      0.96      0.96       429
#
#     accuracy                           0.96       878
# ...

# %% [markdown]
# The (above) models trained with the oversampled data improved the recall rate significantly. Random forest classifier (98%) offers the highest accuracy among the three models.

# %% [markdown]
# ## Evaluation of the model using the normal test data

# %% [markdown]
# To evaluate the model trained on oversampled data to predict the failed wafers, we have:
# - Chosen the random forest model trained on oversampled data.
# - Taken the test data with reduced features and normalised the features using the scalar estimator trained with the oversampled data.

# %%
_, X_test_1, _, y_test_1 = train_test_split(dataX, datay, test_size=0.30, random_state=42)

X_test_1 = ssc.transform(X_test_1)

rand_clf = RandomForestClassifier(random_state=42, n_jobs=-1)
rand_clf.fit(X_train_os, y_train_os)
y_predict_rand_clf = rand_clf.predict(X_test_1)

cm_rand_clf = confusion_matrix(y_test_1, y_predict_rand_clf, labels=rand_clf.classes_)
ConfusionMatrixDisplay(cm_rand_clf, display_labels=rand_clf.classes_).plot(include_values=True)

print(classification_report(y_test_1, y_predict_rand_clf))
# Out:
#               precision    recall  f1-score   support
#
#           -1       1.00      1.00      1.00       440
#            1       0.94      0.94      0.94        31
#
#     accuracy                           0.99       471
#    macro avg       0.97      0.97      0.97       471
# weighted avg       0.99      0.99      0.99       471

# %% [markdown]
# <b>The model based on the oversampled data offered a recall rate of 94% for the failed cases in the test dataset.</b>

# %% [markdown]
# # Dimensionality reduction using PCA

# %%
# features
X = pd.read_csv('./data/secom.data', sep=' ', header=None)

# labels
y = pd.read_csv('./data/secom_labels.data', sep=' ', header=None)
y = y.loc[:, [0]]

data = pd.concat([X, y], axis=1)
data.columns.values[-1] = len(data.columns)

# replace the None values with 0s
data = data.replace(np.NaN, 0)

X_pca = data.loc[:, data.columns[:-2]]
y_pca = data.loc[:, data.columns[-1]]

# %%
# Centralise the data
X_pca_1 = X_pca.copy()
X_pca_1 = ssc.fit_transform(X_pca_1)

# model and fitting
pca = PCA(n_components=X_pca_1.shape[1])
X_reduced = pca.fit_transform(X_pca_1)

# cumulative sum of explained variance ratio
cumsum = np.cumsum(pca.explained_variance_ratio_)

# plotting the principal components verses the cumulative sum of variance
fig, ax = plt.subplots()
ax.plot(np.arange(len(cumsum)), cumsum)
ax.set(xlabel='Principal Components (#)', ylabel='cum_sum_explained_variance_ratio')
plt.show()

# the number of components that contribute most to the dataset
cum_var_thr = 0.95
n_pc = np.where(cumsum>=cum_var_thr)[0][0]
print(f'The number of PCs that contribute cumulative varivance {cum_var_thr}: {n_pc}')
# Out:
# The number of PCs that contribute cumulative varivance 0.95: 156

# %%
X_train_pca, X_test_pca, y_train_pca, y_test_pca = train_test_split(X_pca, y_pca, test_size=0.30, random_state=42)

# scale the data
ssc.fit(X_train_pca)

X_train_pca = ssc.transform(X_train_pca)
X_test_pca = ssc.transform(X_test_pca)

# find the principal components
pca = PCA(n_components=cum_var_thr)
pca.fit(X_train_pca)

X_train_pca = pca.transform(X_train_pca)
X_test_pca = pca.transform(X_test_pca)

print(f'Shape of the X_train_pca: {X_train_pca.shape}')
print(f'Shape of the X_test_pca: {X_test_pca.shape}')
# Out:
# Shape of the X_train_pca: (1096, 152)
# Shape of the X_test_pca: (471, 152)

# %% [markdown]
# ## Train and evaluation of the models on principal components

# %%
models = [('Logistic', LogisticRegression(random_state=42, n_jobs=-1)),
          ('Rand_forest', RandomForestClassifier(random_state=42, n_jobs=-1)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train_pca, y_train_pca)
    y_predict_pca = model.predict(X_test_pca)
    cmat = confusion_matrix(y_test_pca, y_predict_pca, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test_pca, y_predict_pca))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       0.95      0.95      0.95       440
#            1       0.31      0.29      0.30        31
#
#     accuracy                           0.91       471
#    macro avg       0.63      0.62      0.63       471
# weighted avg       0.91      0.91      0.91       471
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.94      0.99      0.96       440
#            1       0.38      0.10      0.15        31
#
#     accuracy                           0.93       471
#    macro avg       0.66      0.54      0.56       471
# weighted avg       0.90      0.93      0.91       471
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.94      0.96      0.95       440
#            1       0.14      0.10      0.12        31
#
#     accuracy                           0.90       471
# ...

# %% [markdown]
# ## Oversampling of the Principal components

# %%
# define the undersampling method
oversample = SMOTE(random_state=42)

# transform the dataset
X_pca_os, y_pca_os = oversample.fit_resample(X_pca, y_pca)

#Histogram
y_pca_os.hist(legend=True)
plt.show()

#Pie chart
plt.pie(y_pca_os.value_counts(), labels=['pass', 'fail'], colors = ['green', 'red'], 
        explode = [0, 0.1], autopct = "%.2f%%")
plt.show()

# %%
X_train_pca_os, X_test_pca_os, y_train_pca_os, y_test_pca_os = train_test_split(X_pca_os, y_pca_os, test_size=0.30, random_state=42)

X_train_pca_os = ssc.fit_transform(X_train_pca_os)
X_test_pca_os = ssc.transform(X_test_pca_os)

# %% [markdown]
# ## Train and evaluation of the oversampled principal components

# %%
models = [('Logistic', LogisticRegression(random_state=42, n_jobs=-1)),
          ('Rand_forest', RandomForestClassifier(random_state=42, n_jobs=-1)),
          ('Grad_boost', GradientBoostingClassifier(random_state=42))]

for name, model in models:
    model.fit(X_train_pca_os, y_train_pca_os)
    y_predict_pca_os = model.predict(X_test_pca_os)
    cmat = confusion_matrix(y_test_pca_os, y_predict_pca_os, labels=model.classes_)
    
    print(f'{name}\n')
    print(classification_report(y_test_pca_os, y_predict_pca_os))
    ConfusionMatrixDisplay(cmat, display_labels=model.classes_).plot(include_values=True)
    plt.show()
# Out:
# Logistic
#
#               precision    recall  f1-score   support
#
#           -1       1.00      0.82      0.90       449
#            1       0.84      1.00      0.91       429
#
#     accuracy                           0.91       878
#    macro avg       0.92      0.91      0.91       878
# weighted avg       0.92      0.91      0.91       878
# Rand_forest
#
#               precision    recall  f1-score   support
#
#           -1       0.99      0.99      0.99       449
#            1       0.99      0.99      0.99       429
#
#     accuracy                           0.99       878
#    macro avg       0.99      0.99      0.99       878
# weighted avg       0.99      0.99      0.99       878
# Grad_boost
#
#               precision    recall  f1-score   support
#
#           -1       0.95      0.96      0.96       449
#            1       0.96      0.95      0.96       429
#
#     accuracy                           0.96       878
# ...

# %% [markdown]
# The (above) models, based on the oversampled principal components, are providing almost the same observations using the oversampled data of the reduced features dataset. Random forest classifier provides the highest accuracy (99%) among the three models.

# %% [markdown]
# # Summary
# - Different models (regression, random forest, and gradient boosting classfiers) are trained on the data that is scaled and shortened.
# - Having a strong bias in the data towards pass class, the models could not provide even a decent racall accuracy
#     - Regression classifier provided 29% recall accuracy
#     - Others provided almost 0% recall accuracy
# - Undersapmling and oversampling techniques are used to improve the racall accuracy of the models
#     - While there is a little improvement in the recall acuuracy with the undersampling, a significant improvement is observed for the oversampled data
#     - Random forest and gradient boosting models provided highest accuracies (up to 97 - 99%)
# - PCA model is used to extract the most contributing features with a threshold (0.95) in the cumulative sum of the variance
#     - Number of extracted principal components is 152
#     - Different models are trained on the principle components
#         - All the models provided alomost the same accuracy of the models that are trained on the normal data
#         - Oversample components provided the same accuracy of the models trained with the oversampled normal data
